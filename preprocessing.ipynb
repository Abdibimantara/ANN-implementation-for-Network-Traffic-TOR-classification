# %%
import pandas as pd
import numpy as np
from scipy.io.arff import loadarff

# %%
TOR_dataset_raw = loadarff("TimeBasedFeatures-15s-TOR-NonTOR-15.arff")
TOR_dataset_raw
# Out:
# (array([(13978645., 1.7000000e+01, 7.0000000e+00, 2.249885e+06, 2.064514e+06,  215483.375   ,  254157.181818, 484527.921325, 462592.986971,  8.656061,  3046.003386,  7., 2064514., 116488.708333, 334260.192004,  1.363299e+06, 2254176.2     ,  3.870047e+06, 1010713.698022,  1.147658e+06, 1533121.8     ,  2.064514e+06,  421832.929403, b'NONTOR'),
#         ( 5545334., 3.0000000e+01, 6.0000000e+00, 2.349340e+06, 2.315198e+06,  267851.55    ,  291859.684211, 662553.265035, 667200.262669,  7.393603,  3556.683872,  6., 2297754., 138633.35    , 468135.293018,  2.347008e+06, 2656002.      ,  2.964996e+06,  436983.505491,  1.978303e+06, 2138028.5     ,  2.297754e+06,  225885.968355, b'NONTOR'),
# ...

# %%
TOR_dataset = np.array(TOR_dataset_raw[0])
TOR_dataset
# Out:
# array([(13978645., 1.7000000e+01, 7.0000000e+00, 2.249885e+06, 2.064514e+06,  215483.375   ,  254157.181818, 484527.921325, 462592.986971,  8.656061,  3046.003386,  7., 2064514., 116488.708333, 334260.192004,  1.363299e+06, 2254176.2     ,  3.870047e+06, 1010713.698022,  1.147658e+06, 1533121.8     ,  2.064514e+06,  421832.929403, b'NONTOR'),
#        ( 5545334., 3.0000000e+01, 6.0000000e+00, 2.349340e+06, 2.315198e+06,  267851.55    ,  291859.684211, 662553.265035, 667200.262669,  7.393603,  3556.683872,  6., 2297754., 138633.35    , 468135.293018,  2.347008e+06, 2656002.      ,  2.964996e+06,  436983.505491,  1.978303e+06, 2138028.5     ,  2.297754e+06,  225885.968355, b'NONTOR'),
# ...

# %%
dataset = pd.DataFrame(TOR_dataset)
dataset
# Out:
#         duration  total_fiat  total_biat   min_fiat   min_biat      max_fiat  \
# 0     13978645.0        17.0         7.0  2249885.0  2064514.0  2.154834e+05
# 1      5545334.0        30.0         6.0  2349340.0  2315198.0  2.678515e+05
# 2     14701087.0        20.0         5.0  5881392.0  5932194.0  2.845729e+05
# 3        57245.0        -1.0        -1.0       -1.0       -1.0  0.000000e+00
# 4        57532.0        -1.0        -1.0       -1.0       -1.0  0.000000e+00
# ...          ...         ...         ...        ...        ...           ...
# 3306  14986348.0  14986078.0  14986059.0       13.0       12.0  8.700700e+04
# 3307  14996861.0  14996651.0  14996584.0      267.0       16.0  7.365000e+04
# 3308  14979149.0  14955242.0  14979149.0       85.0       20.0  7.561800e+04
# 3309  14981021.0  14907075.0  14981021.0       76.0       15.0  5.522154e+06
# 3310  14990545.0  14990317.0  14990345.0       13.0       46.0  9.686700e+04
#
# ...

# %%
dataset.to_csv('dataset2.csv')
